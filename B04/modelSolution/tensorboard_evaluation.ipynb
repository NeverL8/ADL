# %%
# Load the TensorBoard notebook extension 
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# read logfiles from the GNNEncoder training
# %tensorboard --logdir "logs/GNNEncoder/2026-05-26_19-59-53/"
# Out:
# Reusing TensorBoard on port 6015 (pid 11842), started 0:00:00 ago. (Use '!kill 11842' to kill it.)
#       <iframe id="tensorboard-frame-2a5ca5af0f9cf92e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2a5ca5af0f9cf92e");
#           const url = new URL("http://localhost");
#           const port = 6015;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
